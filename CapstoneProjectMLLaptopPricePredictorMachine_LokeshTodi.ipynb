# %% [markdown]
# <a href="https://colab.research.google.com/github/LokeCoder11/Projects/blob/main/CapstoneProjectMLLaptopPricePredictorMachine_LokeshTodi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup IDE Environment

# %%
# !pip install pandas numpy scikit-learn
import pandas as pd
import numpy as np
import openpyxl #to read xls
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Setup Directory

# %%
import os
os.getcwd() # Get the current directory
# Out:
# 'C:\\Users\\hp\\Downloads\\MachineLearningCapstoneProjLokeshTodi'

# %%
ls # Command to see the folder available
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 4107-BEBB
#
#  Directory of C:\Users\hp\Downloads\MachineLearningCapstoneProjLokeshTodi
#
#
#  Directory of C:\Users\hp\Downloads\MachineLearningCapstoneProjLokeshTodi
#
#
#  Directory of C:\Users\hp\Downloads\MachineLearningCapstoneProjLokeshTodi
#
#
#  Directory of C:\Users\hp\Downloads\MachineLearningCapstoneProjLokeshTodi
#
#
#  Directory of C:\Users\hp\Downloads\MachineLearningCapstoneProjLokeshTodi
#
#
#  Directory of C:\Users\hp\Downloads\MachineLearningCapstoneProjLokeshTodi
#
#
#  Directory of C:\Users\hp\Downloads\MachineLearningCapstoneProjLokeshTodi
# File Not Found

# %%
# Setting up directory helps access the files easily.
os.chdir('C:\\Users\\hp\\Downloads\\MachineLearningCapstoneProjLokeshTodi')
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Downloads\\MachineLearningCapstoneProjLokeshTodi'

# %% [markdown]
# # Create Dataframe by Reading File in Target Directory

# %%
# Example of loading the file
df = pd.read_csv('laptop.csv')
df.head(1)
# Out:
#    Unnamed: 0.1  Unnamed: 0 Company   TypeName Inches  \
# 0             0         0.0   Apple  Ultrabook   13.3
#
#                      ScreenResolution                   Cpu  Ram     Memory  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB  128GB SSD
#
#                             Gpu  OpSys  Weight       Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  71378.6832

# %% [markdown]
# # Basic Inspection of dataset -
# * shape,
# * info()
# * isnull().sum()
# * duplicated().sum()
# * head(n),
# * tail(n),
# * columns,
# * describe(),

# %%
df.shape
# Out:
# (1303, 13)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0.1         0
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0 Company   TypeName Inches  \
# 0             0         0.0   Apple  Ultrabook   13.3
# 1             1         1.0   Apple  Ultrabook   13.3
# 2             2         2.0      HP   Notebook   15.6
# 3             3         3.0   Apple  Ultrabook   15.4
# 4             4         4.0   Apple  Ultrabook   13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# ...

# %%
df.tail(5)
# Out:
#       Unnamed: 0.1  Unnamed: 0 Company            TypeName Inches  \
# 1298          1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299          1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300          1300      1300.0  Lenovo            Notebook     14
# 1301          1301      1301.0      HP            Notebook   15.6
# 1302          1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df.head(30)
# Out:
#     Unnamed: 0.1  Unnamed: 0 Company            TypeName Inches  \
# 0              0         0.0   Apple           Ultrabook   13.3
# 1              1         1.0   Apple           Ultrabook   13.3
# 2              2         2.0      HP            Notebook   15.6
# 3              3         3.0   Apple           Ultrabook   15.4
# 4              4         4.0   Apple           Ultrabook   13.3
# 5              5         5.0    Acer            Notebook   15.6
# 6              6         6.0   Apple           Ultrabook   15.4
# 7              7         7.0   Apple           Ultrabook   13.3
# 8              8         8.0    Asus           Ultrabook     14
# 9              9         9.0    Acer           Ultrabook     14
# 10            10        10.0      HP            Notebook   15.6
# 11            11        11.0      HP            Notebook   15.6
# 12            12        12.0   Apple           Ultrabook   15.4
# 13            13        13.0    Dell            Notebook   15.6
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Company', 'TypeName', 'Inches',
#        'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price'],
#       dtype='object')

# %%
df.describe() # Inspection of continous data ONLY
# Out:
#        Unnamed: 0.1   Unnamed: 0          Price
# count    1303.00000  1273.000000    1273.000000
# mean      651.00000   652.674784   59955.814073
# std       376.28801   376.493027   37332.251005
# min         0.00000     0.000000    9270.720000
# 25%       325.50000   327.000000   31914.720000
# 50%       651.00000   652.000000   52161.120000
# 75%       976.50000   980.000000   79333.387200
# max      1302.00000  1302.000000  324954.720000

# %%
df.describe(include= 'all') # Analysis of continous & Categorical data
# Out:
#         Unnamed: 0.1   Unnamed: 0 Company  TypeName Inches   ScreenResolution  \
# count     1303.00000  1273.000000    1273      1273   1273               1273
# unique           NaN          NaN      19         6     25                 40
# top              NaN          NaN  Lenovo  Notebook   15.6  Full HD 1920x1080
# freq             NaN          NaN     290       710    640                495
# mean       651.00000   652.674784     NaN       NaN    NaN                NaN
# std        376.28801   376.493027     NaN       NaN    NaN                NaN
# min          0.00000     0.000000     NaN       NaN    NaN                NaN
# 25%        325.50000   327.000000     NaN       NaN    NaN                NaN
# 50%        651.00000   652.000000     NaN       NaN    NaN                NaN
# 75%        976.50000   980.000000     NaN       NaN    NaN                NaN
# max       1302.00000  1302.000000     NaN       NaN    NaN                NaN
#
# ...

# %%
df.info() # Information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0.1      1303 non-null   int64
#  1   Unnamed: 0        1273 non-null   float64
#  2   Company           1273 non-null   object
#  3   TypeName          1273 non-null   object
#  4   Inches            1273 non-null   object
#  5   ScreenResolution  1273 non-null   object
#  6   Cpu               1273 non-null   object
#  7   Ram               1273 non-null   object
#  8   Memory            1273 non-null   object
#  9   Gpu               1273 non-null   object
#  10  OpSys             1273 non-null   object
#  11  Weight            1273 non-null   object
#  12  Price             1273 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %% [markdown]
# # Clean Null and Duplicate

# %%
df = df.dropna() # Remove all rows having NaN anywhere, since entire row is NaN whereever NaN Present

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0.1      1273 non-null   int64
#  1   Unnamed: 0        1273 non-null   float64
#  2   Company           1273 non-null   object
#  3   TypeName          1273 non-null   object
#  4   Inches            1273 non-null   object
#  5   ScreenResolution  1273 non-null   object
#  6   Cpu               1273 non-null   object
#  7   Ram               1273 non-null   object
#  8   Memory            1273 non-null   object
#  9   Gpu               1273 non-null   object
#  10  OpSys             1273 non-null   object
#  11  Weight            1273 non-null   object
#  12  Price             1273 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 139.2+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1        0
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0.1'],inplace=True)
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 119.3+ KB

# %%
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
#remove gb and kg to convert both column to numeric type from object type
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df['Weight'] = pd.to_numeric(df['Weight'], errors='coerce')
df['Inches'] = pd.to_numeric(df['Inches'], errors='coerce') # Replace non-numeric values with NaN

# %%
print(df.isnull().sum())
# Out:
# Company             0
# TypeName            0
# Inches              1
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              1
# Price               0
# dtype: int64

# %%
df['Weight'] = df['Weight'].fillna(df['Weight'].mean()) #fill weight 1 NaN value with Mean
df['Inches'] = df['Inches'].fillna(df['Inches'].mean()) #fill Inches 1 NaN value with Mean

# %%
print(df.isnull().sum())
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
#Convert Data Type of Number Columns
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')
df['Inches'] = df['Inches'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   int32
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   float32
#  10  Price             1273 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 109.4+ KB

# %%
sns.distplot(df['Price']) #Check distribution of price Data which seems to be skewed
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                495
# 1366x768                                         274
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         52
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  14
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160                9
# 4K Ultra HD 3840x2160                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# Touchscreen 2560x1440                              6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 796     Asus  Notebook    14.0                     1366x768
# 723     Dell    Gaming    17.3        4K Ultra HD 3840x2160
# 604     Dell  Notebook    15.6                     1366x768
# 1076  Lenovo  Notebook    15.6  IPS Panel Full HD 1920x1080
# 245     Dell  Notebook    15.6            Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 796   Intel Celeron Dual Core N3350 1.1GHz    4    32GB Flash Storage
# 723            Intel Core i7 7700HQ 2.8GHz   32    1TB SSD +  1TB HDD
# 604               Intel Core i3 6006U 2GHz    4               1TB HDD
# 1076           Intel Core i5 6300HQ 2.3GHz    4               1TB HDD
# 245             Intel Core i7 8550U 1.8GHz    8  128GB SSD +  2TB HDD
#
#                           Gpu       OpSys  Weight       Price  Touchscreen
# 796     Intel HD Graphics 500  Windows 10    1.63   15930.720            0
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ips'>

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True) #ScreenResolution Split into 2 column

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#      Company     TypeName  Inches                 ScreenResolution  \
# 236     Acer     Notebook    15.6                         1366x768
# 1259     MSI       Gaming    15.6                Full HD 1920x1080
# 433   Lenovo  Workstation    15.6  IPS Panel 4K Ultra HD 3840x2160
# 605      MSI       Gaming    15.6            4K Ultra HD 3840x2160
# 276     Dell     Notebook    17.3                Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 236      Intel Core i3 6006U 2GHz    4               1TB HDD
# 1259  Intel Core i7 6700HQ 2.6GHz    8  128GB SSD +  1TB HDD
# 433    Intel Core i7 7600U 2.8GHz   16             512GB SSD
# 605   Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  2TB HDD
# 276    Intel Core i7 8550U 1.8GHz    8  128GB SSD +  1TB HDD
#
#                           Gpu       OpSys  Weight      Price  Touchscreen  \
# 236     Intel HD Graphics 520       Linux     2.1   20779.20            0
# ...

# %%
#Extract Y value from ScreenResolution's remaining info
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['X_res'] = df['X_res'].astype('int') #convert both column to number data type
df['Y_res'] = df['Y_res'].astype('int')

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   int32
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   float32
#  10  Price             1273 non-null   float64
#  11  Touchscreen       1273 non-null   int64
#  12  Ips               1273 non-null   int64
#  13  X_res             1273 non-null   int32
#  14  Y_res             1273 non-null   int32
#  15  ppi               1273 non-null   float64
# ...

# %% [markdown]
# # Check Correlation of main features to Price

# %%
# Create a smaller DataFrame with only numeric columns
df_small = df[['Inches', 'Ram', 'Weight', 'Price', 'Touchscreen', 'Ips', 'X_res', 'Y_res','ppi']]

# Calculate the correlation of the smaller DataFrame
df_small.corr()['Price']  #check correlation of all numeric column to price
# Out:
# Inches         0.044622
# Ram            0.685648
# Weight         0.175913
# Price          1.000000
# Touchscreen    0.188994
# Ips            0.254851
# X_res          0.557556
# Y_res          0.554069
# ppi            0.468783
# Name: Price, dtype: float64

# %%
df
# Out:
#         Company            TypeName     Inches  \
# 0         Apple           Ultrabook  13.300000
# 1         Apple           Ultrabook  13.300000
# 2            HP            Notebook  15.600000
# 3         Apple           Ultrabook  15.400000
# 4         Apple           Ultrabook  13.300000
# 5          Acer            Notebook  15.600000
# 6         Apple           Ultrabook  15.400000
# 7         Apple           Ultrabook  13.300000
# 8          Asus           Ultrabook  14.000000
# 9          Acer           Ultrabook  14.000000
# 10           HP            Notebook  15.600000
# 11           HP            Notebook  15.600000
# 12        Apple           Ultrabook  15.400000
# 13         Dell            Notebook  15.600000
# 14        Apple           Ultrabook  12.000000
# 15        Apple           Ultrabook  13.300000
# 16         Dell            Notebook  15.600000
# 17        Apple           Ultrabook  15.400000
# 18       Lenovo            Notebook  15.600000
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Create a label encoder object
le = LabelEncoder()

# Fit the encoder to the 'Company' column and transform it to numeric labels
df['Brand_Name_encoded'] = le.fit_transform(df['Company'])

# Now you can calculate the correlation between 'Brand_Name_encoded' and 'Prices'
correlation = df[['Brand_Name_encoded', 'Price']].corr()
correlation
# Out:
#                     Brand_Name_encoded     Price
# Brand_Name_encoded            1.000000  0.140461
# Price                         0.140461  1.000000

# %% [markdown]
# # Remove unnecessary Columns

# %%
df.drop(columns=['ScreenResolution'],inplace=True) # Drop column which is not required

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips  X_res  Y_res         ppi  Brand_Name_encoded
# 0   71378.6832            0    1   2560   1600  226.983005                   1
# ...

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi  Brand_Name_encoded
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz               183
# Intel Core i7 7700HQ 2.8GHz              142
# Intel Core i7 7500U 2.7GHz               128
# Intel Core i7 8550U 1.8GHz                72
# Intel Core i5 8250U 1.6GHz                68
# Intel Core i5 6200U 2.3GHz                66
# Intel Core i3 6006U 2GHz                  62
# Intel Core i7 6500U 2.5GHz                49
# Intel Core i7 6700HQ 2.6GHz               43
# Intel Core i3 7100U 2.4GHz                37
# Intel Core i5 7300HQ 2.5GHz               33
# Intel Celeron Dual Core N3350 1.1GHz      30
# Intel Celeron Dual Core N3060 1.6GHz      27
# Intel Core i7 6600U 2.6GHz                17
# Intel Core i3 6006U 2.0GHz                16
# Intel Pentium Quad Core N4200 1.1GHz      14
# Intel Core i5 7300U 2.6GHz                14
# Intel Core i7 7600U 2.8GHz                13
# Intel Core i5 6300U 2.4GHz                11
# Intel Celeron Dual Core N3050 1.6GHz      11
# Intel Pentium Quad Core N3710 1.6GHz      11
# ...

# %%
#first we will extract Name of CPU which is first 3 words from Cpu column
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
# and then we will check which processor it is
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.drop(columns=['Brand_Name_encoded'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu Name      Cpu brand
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True) #Remove Unnecessary Columns

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         ppi      Cpu brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        401
# 1TB HDD                          217
# 500GB HDD                        130
# 512GB SSD                        116
# 128GB SSD +  1TB HDD              92
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              71
# 32GB Flash Storage                37
# 2TB HDD                           16
# 64GB Flash Storage                14
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           13
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          4
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  500GB HDD             2
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         ppi      Cpu brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Memory'] = df['Memory'].str.strip()

# %%
df.sample(5)
# Out:
#         Company   TypeName  Ram                Memory  \
# 238        Asus     Gaming   32  512GB SSD +  1TB HDD
# 449   Microsoft  Ultrabook   16             512GB SSD
# 1295       Dell   Notebook    8               1TB HDD
# 702      Lenovo   Notebook    8               1TB HDD
# 232      Lenovo     Gaming   16  256GB SSD +  1TB HDD
#
#                                Gpu         OpSys  Weight        Price  \
# 238        Nvidia GeForce GTX 1080    Windows 10    4.70  207259.2000
# 449   Intel Iris Plus Graphics 640  Windows 10 S    1.25  137941.9200
# 1295            AMD Radeon R5 M430         Linux    2.30   42943.1472
# 702                  AMD Radeon R7    Windows 10    2.20   22857.1200
# 232        Nvidia GeForce GTX 1060    Windows 10    3.20   79866.7200
#
#       Touchscreen  Ips         ppi      Cpu brand
# 238             0    0  127.335675  Intel Core i7
# 449             1    0  200.842560  Intel Core i7
# 1295            0    0  100.454670  Intel Core i7
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand
# 0   71378.6832            0    1  226.983005  Intel Core i5
# 1   47895.5232            0    0  127.677940  Intel Core i5
# 2   30636.0000            0    0  141.211998  Intel Core i5
# 3  135195.3360            0    1  220.534624  Intel Core i7
# 4   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620             271
# Intel HD Graphics 520             181
# Intel UHD Graphics 620             66
# Nvidia GeForce GTX 1050            64
# Nvidia GeForce GTX 1060            48
# Nvidia GeForce 940MX               42
# Intel HD Graphics 500              39
# AMD Radeon 530                     39
# Intel HD Graphics 400              34
# Intel HD Graphics                  29
# Nvidia GeForce GTX 1070            29
# Nvidia GeForce GTX 1050 Ti         27
# AMD Radeon R5 M430                 22
# Nvidia GeForce 930MX               20
# AMD Radeon 520                     16
# Nvidia GeForce MX150               15
# Intel HD Graphics 515              15
# AMD Radeon R7 M445                 14
# Nvidia GeForce GTX 960M            14
# Intel HD Graphics 615              14
# Intel HD Graphics 505              12
# Nvidia GeForce 920MX               12
# AMD Radeon R5                      11
# Nvidia GeForce GTX 980M            10
# ...

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand Gpu brand
# 0   71378.6832            0    1  226.983005  Intel Core i5     Intel
# 1   47895.5232            0    0  127.677940  Intel Core i5     Intel
# 2   30636.0000            0    0  141.211998  Intel Core i5     Intel
# 3  135195.3360            0    1  220.534624  Intel Core i7       AMD
# 4   96095.8080            0    1  226.983005  Intel Core i5     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     703
# Nvidia    393
# AMD       176
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     703
# Nvidia    393
# AMD       176
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand Gpu brand
# 0  226.983005  Intel Core i5     Intel
# 1  127.677940  Intel Core i5     Intel
# 2  141.211998  Intel Core i5     Intel
# 3  220.534624  Intel Core i7       AMD
# 4  226.983005  Intel Core i5     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1047
# No OS             63
# Linux             61
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand Gpu brand                  os
# 0  226.983005  Intel Core i5     Intel                 Mac
# 1  127.677940  Intel Core i5     Intel                 Mac
# 2  141.211998  Intel Core i5     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7       AMD                 Mac
# 4  226.983005  Intel Core i5     Intel                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1272 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1272 non-null   object
#  1   TypeName     1272 non-null   object
#  2   Ram          1272 non-null   int32
#  3   Weight       1272 non-null   float32
#  4   Price        1272 non-null   float64
#  5   Touchscreen  1272 non-null   int64
#  6   Ips          1272 non-null   int64
#  7   ppi          1272 non-null   float64
#  8   Cpu brand    1272 non-null   object
#  9   Gpu brand    1272 non-null   object
#  10  os           1272 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(5)
# memory usage: 109.3+ KB

# %%
# Create a smaller DataFrame with only numeric columns
df_small2 = df[['Ram', 'Weight', 'Price', 'Touchscreen', 'Ips', 'ppi']]

# Calculate the correlation of the smaller DataFrame
df_small2.corr()['Price']  #check correlation of all numeric column to price
# Out:
# Ram            0.685521
# Weight         0.175433
# Price          1.000000
# Touchscreen    0.190738
# Ips            0.255987
# ppi            0.470701
# Name: Price, dtype: float64

# %%
sns.heatmap(df_small2.corr());

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X.shape
# Out:
# (1272, 10)

# %%
y.shape
# Out:
# (1272,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train.shape
# Out:
# (1081, 10)

# %%
X_train.head()
# Out:
#     Company  TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 734  Lenovo  Notebook    8    1.44            0    1  165.632118
# 22       HP  Notebook    4    1.86            0    0  100.454670
# 810      HP    Gaming   12    3.74            0    1  127.335675
# 282  Lenovo    Gaming    8    2.50            0    1  141.211998
# 764    Dell  Notebook    4    1.65            0    0  117.826530
#
#          Cpu brand Gpu brand                  os
# 734  Intel Core i5     Intel             Windows
# 22   AMD Processor       AMD  Others/No OS/Linux
# 810  Intel Core i7       AMD             Windows
# 282  Intel Core i5    Nvidia             Windows
# 764  Intel Core i3     Intel             Windows

# %% [markdown]
# # Preparing IDE for ML

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# # LINEAR REGRESSION ML MODEL

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0, 1, 7, 8, 9])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.2f}")

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# Mean Squared Error: 0.13
# R2 score 0.6153812485431329
# MAE 0.23647779271965017

# %% [markdown]
# # GRADIENT BOOSTING REGRESSOR ML MODEL

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0, 1, 7, 8, 9])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.2f}")

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# Mean Squared Error: 0.07
# R2 score 0.7988536980980752
# MAE 0.19708746567551727

# %% [markdown]
# # RANDOM FOREST REGRESSOR ML MODEL

# %%
step1 = ColumnTransformer(transformers=[

('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0, 1, 7, 8, 9])

],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,

random_state=3,

max_samples=0.5,

max_features=0.75,

max_depth=15)

pipe = Pipeline([

('step1',step1),

('step2',step2)

])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)


mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.2f}")

print('R2 score',r2_score(y_test,y_pred))

print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# Mean Squared Error: 0.06
# R2 score 0.8175690893866111
# MAE 0.1816794961983881

# %% [markdown]
# # Exporting the Model - Rerun Final Model & df

# %%
df
# Out:
#         Company            TypeName  Ram     Weight        Price  Touchscreen  \
# 0         Apple           Ultrabook    8   1.370000   71378.6832            0
# 1         Apple           Ultrabook    8   1.340000   47895.5232            0
# 2            HP            Notebook    8   1.860000   30636.0000            0
# 3         Apple           Ultrabook   16   1.830000  135195.3360            0
# 4         Apple           Ultrabook    8   1.370000   96095.8080            0
# 5          Acer            Notebook    4   2.100000   21312.0000            0
# 6         Apple           Ultrabook   16   2.040000  114017.6016            0
# 7         Apple           Ultrabook    8   1.340000   61735.5360            0
# 8          Asus           Ultrabook   16   1.300000   79653.6000            0
# 9          Acer           Ultrabook    8   1.600000   41025.6000            0
# 10           HP            Notebook    4   1.860000   20986.9920            0
# ...

# %%
step1 = ColumnTransformer(transformers=[

('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0, 1, 7, 8, 9])

],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,

random_state=3,

max_samples=0.5,

max_features=0.75,

max_depth=15)

pipe = Pipeline([

('step1',step1),

('step2',step2)

])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)


mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.2f}")

print('R2 score',r2_score(y_test,y_pred))

print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# Mean Squared Error: 0.06
# R2 score 0.8175690893866111
# MAE 0.1816794961983881

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))
df.to_csv("df.csv", index=False)

# %% [markdown]
# # Create New pycharm Project for localhost checking of ML model in working condition with following code :
#
# import streamlit as st
# import pickle
# import numpy as np
#
# # laptop_price_prediction
#
# # import the model
# pipe = pickle.load(open('pipe.pkl', 'rb'))
# df = pickle.load(open('df.pkl', 'rb'))
#
# st.title("Laptop Price Predictor")
#
# # brand
# company = st.selectbox('Brand', df['Company'].unique())
#
# # type of laptop
# type = st.selectbox('Type', df['TypeName'].unique())
#
# # Ram
# ram = st.selectbox('RAM(in GB)', df['Ram'].unique())
#
# # weight
# weight = st.selectbox('Weight of the Laptop(in Kg)', df['Weight'].unique())
#
# # Touchscreen
# touchscreen = st.selectbox('Touchscreen', ['No', 'Yes'])
#
# # IPS
# ips = st.selectbox('IPS', ['No', 'Yes'])
#
# # PPI
# ppi = st.selectbox('PPI(approx)', df['Weight'].unique())
#
# # cpu
# cpu = st.selectbox('CPU', df['Cpu brand'].unique())
#
# # gpu
# gpu = st.selectbox('GPU', df['Gpu brand'].unique())
#
# # os
# os = st.selectbox('OS', df['os'].unique())
#
# ```
# if st.button('Predict Price'):
#     # query
#     if touchscreen == 'Yes':
#         touchscreen = 1
#     else:
#         touchscreen = 0
#
#     if ips == 'Yes':
#         ips = 1
#     else:
#         ips = 0
#
#     query = np.array([company, type, ram, weight, touchscreen, ips, ppi, cpu, hdd, ssd, gpu, os])
#
#     query = query.reshape(1, 10)
#     st.title("The predicted price of this configuration is " + str(int(np.exp(pipe.predict(query)[0]))))
# ```
#
# # in local terminal run -
# * pip install streamlit
# * pip install sklearn
# * pip install scikit-learn
# * streamlit run app.py
# * click on localhost link generated for GUI display
